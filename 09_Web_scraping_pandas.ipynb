# %%
# !pip install html5lib

# %%
import pandas as pd

# %% [markdown]
# ### 네이버 주식 - 엘지전자 페이지

# %%
id_list = ['035420','066570']

# %%
for id_ in id_list:
    base_url = "http://finance.naver.com/item/main.nhn?code="
    target_url = base_url + id_
    
    data = pd.read_html(target_url, encoding='cp949')
   
    print(target_url)
    print(data[2])
# Out:
# http://finance.naver.com/item/main.nhn?code=035420
#       날짜        종가        전일비      외국인        기관
# 0    NaN       NaN        NaN      NaN       NaN
# 1  04/27  197500.0  상향  5,000   -21588   +32,824
# 2  04/24  192500.0  상향  2,500  +32,575   +24,741
# 3  04/23  190000.0  상향  8,000   +6,365  +243,861
# 4  04/22  182000.0  상향  3,500   -13512   +31,299
# 5  04/21  178500.0  하향  1,500     -216   +31,927
# 6  04/20  180000.0  상향  1,000  +73,485    -51463
# 7    NaN       NaN        NaN      NaN       NaN
# http://finance.naver.com/item/main.nhn?code=066570
#       날짜       종가        전일비      외국인       기관
# 0    NaN      NaN        NaN      NaN      NaN
# 1  04/27  53400.0    상향  800  +35,747  +68,710
# 2  04/24  52600.0    하향  700   -15971   -63604
# 3  04/23  53300.0    상향  900  +74,538  +13,471
# 4  04/22  52400.0    하향  200  +13,787  -206653
# 5  04/21  52600.0  하향  1,200  +17,237  -128644
# 6  04/20  53800.0    하향  700  -131493   -85007
# 7    NaN      NaN        NaN      NaN      NaN

# %%
data
# Out:
# [                    0                                        1  \
#  0  전일  53,400  53,400  고가  54,50054,500  (상한가  69,40069,400  )
#  1    시가  53,80053,800        저가  53,10053,100  (하한가  37,400  )
#
#                            2
#  0     거래량  472,162  472,162
#  1  거래대금  25,441  25,441  백만  ,      매도상위      거래량    매수상위      거개량
#  0     NaN      NaN     NaN      NaN
#  1    키움증권  71669.0    키움증권  65759.0
#  2  NH투자증권  51795.0  미래에셋대우  56759.0
#  3  신한금융투자  37764.0  신한금융투자  46271.0
#  4  미래에셋대우  37693.0  NH투자증권  42443.0
#  5      삼성  34745.0      삼성  40498.0
#  6  외국계추정합      0.0  +1,573   1573.0,       날짜       종가        전일비      외국인       기관
#  0    NaN      NaN        NaN      NaN      NaN
#  1  04/27  53400.0    상향  800  +35,747  +68,710
#  2  04/24  52600.0    하향  700   -15971   -63604
#  3  04/23  53300.0    상향  900  +74,538  +13,471
#  4  04/22  52400.0    하향  200  +13,787  -206653
#  5  04/21  52600.0  하향  1,200  +17,237  -128644
#  6  04/20  53800.0    하향  700  -131493   -85007
#  7    NaN      NaN        NaN      NaN      NaN,        주요재무정보   최근 연간 실적                                    최근 분기 실적  \
#         주요재무정보    2017.12    2018.12    2019.12 2020.12(E)    2018.12
#         주요재무정보     IFRS연결     IFRS연결     IFRS연결     IFRS연결     IFRS연결
#  0         매출액  613963.00  613417.00  623062.00  625704.00  157723.00
#  1        영업이익   24685.00   27033.00   24361.00   26028.00     757.00
#  2       당기순이익   18695.00   14728.00    1799.00   11794.00    -807.00
#  3       영업이익률       4.02       4.41       3.91       4.16       0.48
#  4        순이익률       3.04       2.40       0.29       1.88      -0.51
#  5   ROE(지배주주)      13.69       9.03       0.22       7.00       9.03
#  6        부채비율     180.92     171.84     173.12        NaN     171.84
#  7        당좌비율      75.64      72.73      74.78        NaN      72.73
#  8         유보율    1535.94    1658.84    1634.72        NaN    1658.84
#  9      EPS(원)    9543.00    6858.00     173.00    5742.00    -942.00
#  10     PER(배)      11.11       9.08     416.75       9.30       9.08
#  11     BPS(원)   73441.00   79156.00   79582.00   85221.00   79156.00
#  12     PBR(배)       1.44       0.79       0.91       0.63       0.79
#  13   주당배당금(원)     400.00     750.00     750.00     726.00        NaN
#  14   시가배당률(%)       0.38       1.20       1.04        NaN        NaN
#  15    배당성향(%)       4.22      10.96     434.42        NaN        NaN
#
#
#        2019.03    2019.06    2019.09    2019.12 2020.03(E)
#         IFRS연결     IFRS연결     IFRS연결     IFRS연결     IFRS연결
#  0   149151.00  156293.00  157006.00  160612.00  155393.00
#  1     9006.00    6522.00    7815.00    1018.00    8557.00
#  2     5780.00    1060.00    3457.00   -8497.00    3380.00
#  3        6.04       4.17       4.98       0.63       5.51
#  4        3.88       0.68       2.20      -5.29       2.17
#  5        7.59       6.16       4.94       0.22        NaN
#  6      171.18     168.31     170.50     173.12        NaN
#  7       75.14      76.67      76.77      74.78        NaN
#  8     1701.01    1699.94    1722.72    1634.72        NaN
#  9     3157.00     507.00    1350.00   -4841.00    2185.00
#  10      12.41      15.89      16.55     416.75      22.81
#  11   82564.00   83454.00   85198.00   79582.00        NaN
#  12       0.91       0.95       0.79       0.91        NaN
#  13        NaN        NaN        NaN        NaN        NaN
#  14        NaN        NaN        NaN        NaN        NaN
#  15        NaN        NaN        NaN        NaN        NaN  ,            종목명 LG전자*066570 드림어스컴퍼니*060570 아남전자*008700 홈캐스트*064240 삼본전자*111870
#  0          현재가       53500           4955        1620        3580        1585
#  1         전일대비     상향  100         하향  55       하향  5      하향  60      하향  25
#  2          등락률  상향  +0.19%     하향  -1.10%  하향  -0.31%  하향  -1.65%  하향  -1.55%
#  3      시가총액(억)       87551           2817        1249        1184        1028
#  4     외국인비율(%)       30.84           3.77        2.85        4.02        2.60
#  5       매출액(억)      160612            618         580         117          65
#  6      영업이익(억)        1018            -32           2         -45         -12
#  7    조정영업이익(억)        1018            -32           2         -45         -12
#  8   영업이익증가율(%)      -86.97           9.29      -88.06     -728.89     -678.04
#  9     당기순이익(억)       -8497           -247          -4        -123        -219
#  10    주당순이익(원)    -4840.98        -436.80       -4.66     -284.80     -294.71
#  11      ROE(%)         .22         -34.56         .77      -13.86      -14.38
#  12      PER(%)      309.25          -5.78      270.00      -11.59       -5.78
#  13      PBR(배)         .67           2.39        2.17        1.68         .85,           0              1
#  0      시가총액  8조  7,552  억원
#  1    시가총액순위        코스피 29위
#  2     상장주식수      163647814
#  3  액면가l매매단위  5,000원  l  1주,              0          1
#  0  외국인한도주식수(A)  163647814
#  1  외국인보유주식수(B)   50464606
#  2  외국인소진율(B/A)     30.84%,            0                  1
#  0  투자의견l목표주가  4.00매수  l  78,320
#  1   52주최고l최저  83,400  l  41,600,                    0                  1
#  0   PERlEPS(2019.12)   309.25배  l  173원
#  1          추정PERlEPS   9.00배  l  5,742원
#  2  PBRlBPS (2019.12)  0.67배  l  79,582원
#  3      배당수익률l2019.12              1.40%,           0         1
#  0  동일업종 PER  -206.38배
#  1  동일업종 등락률    +0.08%,        매도잔량 호가(20분지연)     매수잔량
#  0       NaN       NaN      NaN
#  1    6275.0     54600      NaN
#  2   26506.0     54500      NaN
#  3   18794.0     54400      NaN
#  4    9568.0     54300      NaN
#  5    4146.0     54200      NaN
#  6    4047.0     54100      NaN
#  7    7700.0     54000      NaN
#  8    3678.0     53900      NaN
#  9    4343.0     53800      NaN
#  10   1989.0     53700      NaN
#  11      NaN       NaN      NaN
#  12      NaN     53600    477.0
#  13      NaN     53500   5469.0
#  14      NaN     53400   5962.0
#  15      NaN     53300   6707.0
#  16      NaN     53200  12804.0
#  17      NaN     53100   5185.0
#  18      NaN     53000  11860.0
#  19      NaN     52900   4008.0
#  20      NaN     52800   3467.0
#  21      NaN     52700   2974.0
#  22      NaN       NaN      NaN
#  23  87046.0      잔량합계  58913.0,               업체명       거래량        전일비
#  0      삼성 인버스 2..   18660.0  상향  6,820
#  1            삼성전자   49550.0    하향  300
#  2             디피씨    9290.0    상향  590
#  3        에이프로젠제..    2340.0     상향  40
#  4      에이프로젠 KI..    3865.0     하향  50
#  5             NaN       NaN        NaN
#  6   KODEX WTI원유..    3165.0    하향  515
#  7            현대로템   18500.0    상향  550
#  8             파미셀   19500.0    상향  250
#  9           S-Oil   68000.0  하향  3,500
#  10           LG화학  361000.0  상향  7,500,            업체명       거래량         전일비
#  0         노랑풍선   14200.0  상한가  3,250
#  1           씨젠   93800.0   하향  2,200
#  2         메디톡스  107100.0   상향  2,200
#  3   에이프로젠 H&..    1330.0     상향  190
#  4        대아티아이    6390.0     상향  100
#  5          NaN       NaN         NaN
#  6          스페코    5140.0     상향  560
#  7         모두투어   13800.0   상향  1,450
#  8         넥슨지티    8440.0   상향  1,410
#  9     셀트리온헬스..   85000.0   하향  1,400
#  10         초록뱀    1735.0      상향  10]

# %%
lg = pd.read_html("http://finance.naver.com/item/main.nhn?code=066570", encoding='cp949')

# %%
type(lg)
# Out:
# list

# %%
len(lg)
# Out:
# 13

# %%
lg[0]
# Out:
#                     0                                        1  \
# 0  전일  53,400  53,400  고가  54,50054,500  (상한가  69,40069,400  )
# 1    시가  53,80053,800        저가  53,10053,100  (하한가  37,400  )
#
#                           2
# 0     거래량  472,367  472,367
# 1  거래대금  25,452  25,452  백만

# %%
type(lg[0])
# Out:
# pandas.core.frame.DataFrame

# %%
lg[1]
# Out:
#      매도상위      거래량    매수상위      거개량
# 0     NaN      NaN     NaN      NaN
# 1    키움증권  71669.0    키움증권  65759.0
# 2  NH투자증권  51795.0  미래에셋대우  56759.0
# 3  신한금융투자  37764.0  신한금융투자  46271.0
# 4  미래에셋대우  37693.0  NH투자증권  42443.0
# 5      삼성  34745.0      삼성  40498.0
# 6  외국계추정합      0.0  +1,573   1573.0

# %%
lg[2]
# Out:
#       날짜       종가        전일비      외국인       기관
# 0    NaN      NaN        NaN      NaN      NaN
# 1  04/27  53400.0    상향  800  +35,747  +68,710
# 2  04/24  52600.0    하향  700   -15971   -63604
# 3  04/23  53300.0    상향  900  +74,538  +13,471
# 4  04/22  52400.0    하향  200  +13,787  -206653
# 5  04/21  52600.0  하향  1,200  +17,237  -128644
# 6  04/20  53800.0    하향  700  -131493   -85007
# 7    NaN      NaN        NaN      NaN      NaN

# %%
lg[3]
# Out:
#        주요재무정보   최근 연간 실적                                    최근 분기 실적  \
#        주요재무정보    2017.12    2018.12    2019.12 2020.12(E)    2018.12
#        주요재무정보     IFRS연결     IFRS연결     IFRS연결     IFRS연결     IFRS연결
# 0         매출액  613963.00  613417.00  623062.00  625704.00  157723.00
# 1        영업이익   24685.00   27033.00   24361.00   26028.00     757.00
# 2       당기순이익   18695.00   14728.00    1799.00   11794.00    -807.00
# 3       영업이익률       4.02       4.41       3.91       4.16       0.48
# 4        순이익률       3.04       2.40       0.29       1.88      -0.51
# 5   ROE(지배주주)      13.69       9.03       0.22       7.00       9.03
# 6        부채비율     180.92     171.84     173.12        NaN     171.84
# 7        당좌비율      75.64      72.73      74.78        NaN      72.73
# 8         유보율    1535.94    1658.84    1634.72        NaN    1658.84
# 9      EPS(원)    9543.00    6858.00     173.00    5742.00    -942.00
# 10     PER(배)      11.11       9.08     416.75       9.30       9.08
# 11     BPS(원)   73441.00   79156.00   79582.00   85221.00   79156.00
# 12     PBR(배)       1.44       0.79       0.91       0.63       0.79
# 13   주당배당금(원)     400.00     750.00     750.00     726.00        NaN
# 14   시가배당률(%)       0.38       1.20       1.04        NaN        NaN
# 15    배당성향(%)       4.22      10.96     434.42        NaN        NaN
#
#
#       2019.03    2019.06    2019.09    2019.12 2020.03(E)
#        IFRS연결     IFRS연결     IFRS연결     IFRS연결     IFRS연결
# 0   149151.00  156293.00  157006.00  160612.00  155393.00
# 1     9006.00    6522.00    7815.00    1018.00    8557.00
# 2     5780.00    1060.00    3457.00   -8497.00    3380.00
# 3        6.04       4.17       4.98       0.63       5.51
# 4        3.88       0.68       2.20      -5.29       2.17
# 5        7.59       6.16       4.94       0.22        NaN
# 6      171.18     168.31     170.50     173.12        NaN
# 7       75.14      76.67      76.77      74.78        NaN
# 8     1701.01    1699.94    1722.72    1634.72        NaN
# 9     3157.00     507.00    1350.00   -4841.00    2185.00
# 10      12.41      15.89      16.55     416.75      22.81
# 11   82564.00   83454.00   85198.00   79582.00        NaN
# 12       0.91       0.95       0.79       0.91        NaN
# 13        NaN        NaN        NaN        NaN        NaN
# 14        NaN        NaN        NaN        NaN        NaN
# 15        NaN        NaN        NaN        NaN        NaN

# %%
lg[4]
# Out:
#            종목명 LG전자*066570 드림어스컴퍼니*060570 아남전자*008700 홈캐스트*064240 삼본전자*111870
# 0          현재가       53600           4950        1625        3580        1585
# 1         전일대비     상향  200         하향  60         보합0      하향  60      하향  25
# 2          등락률  상향  +0.37%     하향  -1.20%       0.00%  하향  -1.65%  하향  -1.55%
# 3      시가총액(억)       87715           2814        1253        1184        1028
# 4     외국인비율(%)       30.84           3.77        2.85        4.02        2.60
# 5       매출액(억)      160612            618         580         117          65
# 6      영업이익(억)        1018            -32           2         -45         -12
# 7    조정영업이익(억)        1018            -32           2         -45         -12
# 8   영업이익증가율(%)      -86.97           9.29      -88.06     -728.89     -678.04
# 9     당기순이익(억)       -8497           -247          -4        -123        -219
# 10    주당순이익(원)    -4840.98        -436.80       -4.66     -284.80     -294.71
# 11      ROE(%)         .22         -34.56         .77      -13.86      -14.38
# 12      PER(%)      309.83          -5.77      270.83      -11.59       -5.78
# 13      PBR(배)         .67           2.39        2.17        1.68         .85

# %%
lg[5]
# Out:
#           0              1
# 0      시가총액  8조  7,715  억원
# 1    시가총액순위        코스피 29위
# 2     상장주식수      163647814
# 3  액면가l매매단위  5,000원  l  1주
